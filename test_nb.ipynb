# %%
import numpy as np
import pandas as pd

data = np.random.randint(5,30,size=10)
df = pd.DataFrame(data, columns=['random_numbers'])

print(df)
# Out:
#    random_numbers
# 0              27
# 1              10
# 2              17
# 3              14
# 4               5
# 5              20
# 6              17
# 7              24
# 8              22
# 9              25

# %%
df.plot()
# Out:
# <AxesSubplot:>
